# %%
# Importing Dependencies
import pandas as pd
import numpy as np

# %%
# Creating reference to CSV file
kushy_prod_data_path = "products-kushy_api.2017-11-14.csv"

# Importing the CSV into a pandas DataFrame
kushy_prod_df = pd.read_csv(kushy_prod_data_path, low_memory=False)

# Looking at the top of the df to get a feel for the data
kushy_prod_df.head(10)
# Out:
#    id                                  name  \
# 0   1           Pre-Roll Package - Pre-roll
# 1   2                     ounce of cannabis
# 2   3                 1/2 ounce of cannabis
# 3   4                 1/4 ounce of cannabis
# 4   5                                   1/8
# 5   6          Nectar Box-The Humboldt Cure
# 6   7         The Humboldt Cure  - Pre-roll
# 7   8  CBD-Rich Recovery Salve - 5ml Sample
# 8   9               CBD-Rich Recovery Salve
# 9  10           Lift Tickets Gucci OG Rosin
#
#                                              slug              brand  \
# 0     the-humboldt-cure-pre-roll-package-pre-roll  The Humboldt Cure
# 1             the-humboldt-cure-ounce-of-cannabis  The Humboldt Cure
# 2         the-humboldt-cure-1-2-ounce-of-cannabis  The Humboldt Cure
# 3         the-humboldt-cure-1-4-ounce-of-cannabis  The Humboldt Cure
# 4                           the-humboldt-cure-1-8  The Humboldt Cure
# 5  the-humboldt-cure-nectar-box-the-humboldt-cure  The Humboldt Cure
# 6    the-humboldt-cure-the-humboldt-cure-pre-roll  The Humboldt Cure
# 7   turtle-bud-cbd-rich-recovery-salve-5ml-sample         Turtle Bud
# 8              turtle-bud-cbd-rich-recovery-salve         Turtle Bud
# 9        lift-tickets-lift-tickets-gucci-og-rosin       Lift Tickets
#
#            category strain   thc    cbd lab_test
# 0  Flowers,Pre-Roll    NaN   NaN    NaN      NaN
# 1               NaN    NaN   NaN    NaN      NaN
# 2               NaN    NaN   NaN    NaN      NaN
# 3               NaN    NaN   NaN    NaN      NaN
# 4               NaN    NaN   NaN    NaN      NaN
# 5               NaN    NaN   NaN    NaN      NaN
# 6  Flowers,Pre-Roll    NaN   NaN    NaN      NaN
# 7          Topical,    NaN   5mg   35mg      NaN
# 8          Topical,    NaN  30mg  210mg      NaN
# 9               NaN    NaN   NaN    NaN      NaN

# %%
# Getting some preliminary descriptive statistics for the columns in the df
kushy_prod_df.describe(include="all")
# Out:
#                  id                   name                    slug  \
# count   17233.00000                  17232                   17233
# unique          NaN                  11976                   17233
# top             NaN  Sour Diesel - Shatter  edipure-edipuffs-100mg
# freq            NaN                     74                       1
# mean     8617.00000                    NaN                     NaN
# std      4974.88293                    NaN                     NaN
# min         1.00000                    NaN                     NaN
# 25%      4309.00000                    NaN                     NaN
# 50%      8617.00000                    NaN                     NaN
# 75%     12925.00000                    NaN                     NaN
# max     17233.00000                    NaN                     NaN
#
#                    brand              category        strain    thc   cbd  \
# count              17232                 16062         17021   4328   785
# unique              1297                    23          2582    462   265
# top     Unknown Producer  Concentrate,Shatter,  ACDC (AC/DC)  100mg  10mg
# freq                2793                  2801          1270    503    49
# mean                 NaN                   NaN           NaN    NaN   NaN
# std                  NaN                   NaN           NaN    NaN   NaN
# min                  NaN                   NaN           NaN    NaN   NaN
# 25%                  NaN                   NaN           NaN    NaN   NaN
# 50%                  NaN                   NaN           NaN    NaN   NaN
# 75%                  NaN                   NaN           NaN    NaN   NaN
# max                  NaN                   NaN           NaN    NaN   NaN
#
#                                                  lab_test
# count                                                 236
# unique                                                193
# top     https://www.cannabisreports.com/lab-tests/5/58...
# freq                                                    8
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
# Looking into the most popular strain
strain_count = kushy_prod_df["strain"].value_counts()

# Converting <strain_count> (i.e. the strain value_counts() series) to a df
strain_count_df1 = strain_count.to_frame()

# Resetting the <strain_count> df's index to numbers
strain_count_df2 = strain_count_df1.reset_index()

# Renaming the <strain_count> df's to appropriate ones
strain_count_df3 = strain_count_df2.rename(columns={"index": "Strain",
                                        "strain": "Count",
                                        })

strain_count_df4 = strain_count_df3.loc[strain_count_df3["Count"] >= 60 , :] # set level to 60 (51%) or 16 (68%)


strain_count_df4.describe().round(2)
# Out:
#          Count
# count    44.00
# mean    195.41
# std     224.88
# min      60.00
# 25%      69.00
# 50%     104.50
# 75%     207.75
# max    1270.00

# %%
# Percent reduction in n of rows(cases) between dfs 3 and 4
(1 - len(strain_count_df4) / len(strain_count_df3)) * 100
# Out:
# 98.29589465530596

# %%
(strain_count_df4["Count"].sum() / strain_count_df3["Count"].sum()).round(2)
# Out:
# 0.51

# %%
# n of rows(cases) in final df
len(strain_count_df4)
# Out:
# 44

# %%
# Notebook Setup
# %matplotlib notebook

# Dependencies
import seaborn as sns
sns.set(color_codes=True)

import matplotlib.pyplot as plt

# sns.kdeplot(strain_count_df3["Count"],
#             bw="silverman",
#             shade=True,
#             #cut=2,
#             label="Bandwidth = Silverman",
            
#            );

# sns.rugplot(strain_count_df3["Count"]);

g = sns.barplot(x="Strain", y="Count", data=strain_count_df4,)
g.set_xticklabels(g.get_xticklabels(), rotation=90,)
plt.gcf().subplots_adjust(bottom=0.60)

plt.savefig('strains.png', dpi=400)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
strain_count_df4
# Out:
#                              Strain  Count
# 0                      ACDC (AC/DC)   1270
# 1                           OG Kush    703
# 2                        Blue Dream    692
# 3                Girl Scout Cookies    542
# 4                         Harlequin    302
# 5                      Sour Tsunami    297
# 6                       Sour Diesel    286
# 7           Granddaddy Purple (GDP)    284
# 8                       Cali Orange    277
# 9                        Jack Herer    274
# 10              Chem Dawg (Chemdog)    219
# 11       Afgoo (Afgooey / Afghooey)    204
# 12                     Green Ribbon    199
# 13          White Fire OG (WiFi OG)    183
# 14                  Sunset Sherbert    182
# 15                Maui Waui (Wowie)    177
# 16         Cherry Pie (Cherry Kush)    171
# 17                  Gorilla Glue #4    165
# 18                          Fire OG    155
# 19                        CB Diesel    147
# 20                         Paris OG    119
# 21                         Headband    107
# 22                 Platinum Cookies    102
# 23                       Blue Widow    100
# 24                        Grape Ape     99
# 25           Jilly Bean (Jillybean)     90
# 26                 Strawberry Cough     85
# 27  San Fernando Valley OG (SFV OG)     82
# 28                Purple Trainwreck     82
# 29                      Green Crack     81
# 30                    Tahoe OG Kush     70
# 31                   Raspberry Kush     69
# 32               Original UK Cheese     69
# 33                    Durban Poison     69
# 34                       Bubba Kush     66
# 35                  Blackberry Kush     66
# 36                           Indica     66
# 37                       Trainwreck     66
# 38                      Pinky Dinky     65
# 39                     Skywalker OG     65
# 40                           Tangie     65
# 41                       Cannatonic     63
# 42                    Lemon OG Kush     63
# 43                          Sour OG     60

# %%
# # Alternate cut (cuts bottom AND top outliers to get 51% differntly)
# strain_count_df5 = strain_count_df3.loc[strain_count_df3["Count"] >= 30 , :]
# strain_count_df6 = strain_count_df5.loc[strain_count_df5["Count"] <= 800 , :]


# strain_count_df6.describe().round(2)

# %%
kushy_prod_df["brand"].value_counts()
# Out:
# Unknown Producer                       2793
# Moxie Seeds & Extracts                  180
# Golden XTRX                             167
# Baked                                   162
# PopNaturals                             145
# Rumpelstiltskin Extracts (Rump Wax)     143
# IncrediMeds                             131
# Glowing Buddha                          124
# Natural Cannabis Company                116
# O.pen VAPE                              113
# Gold Drop                               111
# Nectars 710                             107
# Suspiciously Delicious                  101
# Canna Magic                              97
# Heavenly Sweet                           96
# Delta 11                                 95
# DankMan                                  92
# Bhang                                    92
# Waxology                                 89
# EdiPure                                  88
# The CO2 Company                          86
# Om Extracts                              84
# HGH Extractions                          82
# Waxman Concentrates                      81
# Avocanna Medicinals                      79
# West Coast Cure                          79
# Baked by coco                            77
# OMG Extracts                             76
# Kaneh Company                            76
# Eureka Vapor                             75
#                                        ...
# Drip Ice Cream                            1
# Botanical Elements                        1
# Flying Squirrel Bakery                    1
# BHtOads                                   1
# Amoji                                     1
# ToffeeLand                                1
# OCO                                       1
# Clarity                                   1
# Plus Gum                                  1
# Coastal Chronic                           1
# Talking Trees Farms                       1
# The Bag Lady                              1
# Easy Baked                                1
# Coyote Creations                          1
# Parmagene                                 1
# Hive Honey                                1
# Amber Alchemy                             1
# Mary Jane Xtracts                         1
# Epic Edibles                              1
# Rebirth                                   1
# Pretty Girl Extracts                      1
# Jackalope Extracts                        1
# Crown Point Cannabis                      1
# Amsterdam Sand                            1
# Dank Dynasty                              1
# Resin Ranchers                            1
# Yummy420                                  1
# SF Slab Co.                               1
# Terpoholics                               1
# KnockOut Genetics                         1
# Name: brand, Length: 1297, dtype: int64

# %%
kushy_prod_df["category"].value_counts()

# Looking into the most popular category
category_count = kushy_prod_df["category"].value_counts()

# Converting <category_count> (i.e. the category value_counts() series) to a df
category_count_df1 = category_count.to_frame()

# # Exporting a csv of the df
# category_count_df1.to_csv("category_counts.csv")

category_count_df1
# Out:
#                           category
# Concentrate,Shatter,          2801
# Concentrate,Wax,              2151
# Concentrate,Oil,              1664
# Edibles,Candy,                1443
# Vapes,Vape Cartidge,          1300
# Edibles,                       890
# Edibles,Snack,                 856
# Concentrate,Bubble Hash,       756
# Edibles,Chocolate,             723
# Concentrate,Crumble,Wax,       684
# Edibles,Drink,                 535
# Topical,                       521
# Tincture,                      517
# Edibles,Pill                   365
# Flowers,Pre-Roll               308
# Vapes,Disposable Vape,         189
# Concentrate,Kief,              184
# Topical,Bath,                   97
# Edibles,Spread,                 45
# Concentrate,Topical,RSO         18
# Edibles,Dressing,                8
# Edibles,Soup,                    5
# Edibles,Salt,                    2

# %%
# deciding the cut off
category_count_df2 = category_count_df1.loc[category_count_df1["category"] >= 800 , :]

# %%
# Calculating  how representative the 2nd df is of the 1st df through the proportion of their count volumes 
(category_count_df2["category"].sum() / category_count_df1["category"].sum()).round(2)
# Out:
# 0.69

# %%
category_count_df2
# Out:
#                       category
# Concentrate,Shatter,      2801
# Concentrate,Wax,          2151
# Concentrate,Oil,          1664
# Edibles,Candy,            1443
# Vapes,Vape Cartidge,      1300
# Edibles,                   890
# Edibles,Snack,             856

# %%
thc_count = kushy_prod_df["thc"].value_counts()

thc_count_df1 = thc_count.to_frame()

thc_count_df2 = thc_count_df1.reset_index()

thc_count_df3 = thc_count_df2.rename(columns={"index": "THC",
                                        "thc": "Count",
                                        })

thc_count_df3

# sns.barplot(x="THC", y="Count", data=thc_count_df3,)
# Out:
#           THC  Count
# 0       100mg    503
# 1        50mg    272
# 2       200mg    251
# 3       150mg    187
# 4        60mg    177
# 5       180mg    174
# 6       300mg    165
# 7       120mg    142
# 8       250mg    137
# 9        25mg    119
# 10      500mg    112
# 11       10mg    100
# 12       30mg     92
# 13       40mg     88
# 14       80mg     88
# 15      400mg     68
# 16       20mg     65
# 17      420mg     63
# 18       75mg     60
# 19    1,000mg     51
# 20      147mg     47
# 21      125mg     45
# 22       65mg     44
# 23       15mg     41
# 24    1,260mg     40
# 25       70mg     40
# 26      210mg     39
# 27      160mg     34
# 28       35mg     26
# 29      225mg     25
# ..        ...    ...
# 432      44mg      1
# 433   16.20mg      1
# 434    71.15%      1
# 435    72.16%      1
# 436   95.20mg      1
# 437     104mg      1
# 438    73.90%      1
# 439  147.60mg      1
# 440  105.15mg      1
# 441    43.56%      1
# 442  374.10mg      1
# 443     154mg      1
# 444     747mg      1
# 445    63.10%      1
# 446    80.41%      1
# 447      59mg      1
# 448   89.20mg      1
# 449    74.20%      1
# 450   43.75mg      1
# 451    70.46%      1
# 452   1,800mg      1
# 453    80.22%      1
# 454       68%      1
# 455   85.30mg      1
# 456    69.60%      1
# 457   1,138mg      1
# 458      52mg      1
# 459   10.05mg      1
# 460   41.60mg      1
# 461    71.51%      1
#
# [462 rows x 2 columns]

# %%
thc_count_df4 = thc_count_df3.loc[thc_count_df3["Count"] >= 25, :]

# %%
(thc_count_df4["Count"].sum() / thc_count_df3["Count"].sum()).round(2)
# Out:
# 0.76

# %%
thc_count_df3["THC"].str.contains("%")

thc_count_df_percents = thc_count_df3.loc[thc_count_df3["THC"].str.contains("%") == True, :]

thc_count_df_percents.head()
# Out:
#      THC  Count
# 64   60%      8
# 70   50%      7
# 96   67%      4
# 105  30%      3
# 106  70%      3

# %%
thc_count_df3["THC"].str.contains("mg")

thc_count_df_mgs = thc_count_df3.loc[thc_count_df3["THC"].str.contains("mg") == True, :]

thc_count_df_mgs.head()
# Out:
#      THC  Count
# 0  100mg    503
# 1   50mg    272
# 2  200mg    251
# 3  150mg    187
# 4   60mg    177
