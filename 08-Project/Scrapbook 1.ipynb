# %%
# Importing Dependencies
import pandas as pd
import numpy as np

# %%
# Creating reference to CSV file
kushy_prod_data_path = "products-kushy_api.2017-11-14.csv"

# Importing the CSV into a pandas DataFrame
kushy_prod_df = pd.read_csv(kushy_prod_data_path, low_memory=False)

# Looking at the top of the df to get a feel for the data
kushy_prod_df.head(15)
# Out:
#     id                                        name  \
# 0    1                 Pre-Roll Package - Pre-roll
# 1    2                           ounce of cannabis
# 2    3                       1/2 ounce of cannabis
# 3    4                       1/4 ounce of cannabis
# 4    5                                         1/8
# 5    6                Nectar Box-The Humboldt Cure
# 6    7               The Humboldt Cure  - Pre-roll
# 7    8        CBD-Rich Recovery Salve - 5ml Sample
# 8    9                     CBD-Rich Recovery Salve
# 9   10                 Lift Tickets Gucci OG Rosin
# 10  11         Lift Tickets - 2 Pack White Fire #5
# 11  12  Lift Tickets - 2 Pack Organic Tangie Rosin
# 12  13     Lift Tickets - 2 Pack 805 Oilers Tangie
# 13  14                        Lift Ticket - 1 Pack
# 14  15                                   Salve CBD
#
#                                                  slug                  brand  \
# ...

# %%
kushy_prod_df_thc_percent = kushy_prod_df.loc[kushy_prod_df["thc"].str.contains("%") == True, :]

kushy_prod_df_thc_percent["thc"] = kushy_prod_df_thc_percent["thc"].replace(
    '%', '', regex=True).astype('float')

# kushy_prod_df_thc_percent.sort_values("thc", ascending=True)

# ---------------------------------

# thc_percent_category_group = kushy_prod_df_thc_percent.groupby("category")

# category_avg_thc = pd.DataFrame(thc_percent_category_group["thc"].mean().round(2))

# category_avg_thc.sort_values(by="thc", ascending=False)

kushy_prod_df_thc_percent["category"].value_counts()
# Out:
# C:\Users\Rafael\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# Vapes,Vape Cartidge,        44
# Vapes,Disposable Vape,      30
# Concentrate,Wax,            29
# Concentrate,Oil,            27
# Concentrate,Shatter,        25
# Concentrate,Crumble,Wax,    10
# Concentrate,Bubble Hash,     4
# Name: category, dtype: int64

# %%
kushy_prod_df_thc_mgs = kushy_prod_df.loc[kushy_prod_df["thc"].str.contains("mg") == True, :]

# kushy_prod_df_thc_mgs["thc"] = kushy_prod_df_thc_mgs["thc"].replace(
#     'mg', '', regex=True).astype('float')

kushy_prod_df_thc_mgs["category"].value_counts()
# Out:
# Edibles,Candy,             1017
# Edibles,Snack,              590
# Edibles,Chocolate,          590
# Edibles,                    533
# Edibles,Drink,              391
# Edibles,Pill                276
# Tincture,                   179
# Topical,                    134
# Topical,Bath,                36
# Edibles,Spread,              26
# Edibles,Dressing,             8
# Concentrate,Topical,RSO       6
# Edibles,Soup,                 3
# Edibles,Salt,                 2
# Flowers,Pre-Roll              1
# Name: category, dtype: int64
