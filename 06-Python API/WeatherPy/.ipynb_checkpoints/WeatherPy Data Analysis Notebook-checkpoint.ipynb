# %%
# Importing necessary libraries and api key
import os
import time
import json
import random
import requests
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from citipy import citipy
from config import owm_api_key

# %%
# Making an empty list to hold the randomly selected cities
prelim_city_list = []

# Generating 1000 unique cities using randomly generated coordinates
while len(prelim_city_list) < 1000:
    city = citipy.nearest_city(random.randrange(-90,90), random.randrange(-180,180)).city_name
    
    # Ensuring uniqueness in the city list
    if city not in prelim_city_list:
        prelim_city_list.append(city)

# %%
# Checking number of cities
n_cities = len(prelim_city_list)
print(n_cities)
# Out:
# 1000

# %%
# Creating empty lists to hold weather data for each city and zeroing the loop counter
temp = []
humidity = []
wind = []
cloudiness = []
open_weather_city_number = []
lat = []
lng = []
final_city_list = []
process_number = 0

# Setting up some of the api parameters
url = "api.openweathermap.org/data/2.5/weather?q="
units = "metric"

# Setting up headers for the log (in csv format)
print("Process Number, City Name, City ID")

# Querying the openweathermap api using the cities in the randomly generated list
for city in prelim_city_list:
    if len(final_city_list) < 520:
        query = f"http://{url}{city}&APPID={owm_api_key}&units={units}"
        response = requests.get(query).json()
        process_number = process_number + 1
        time.sleep(1.01) # Delaying by 1.01 secs to stay above the api's 1 query per second limit 
       
        # Attempting to extract each city's temperature, humidity, wind speed, and cloudiness data and filling in the empty lists 
        try:
            temp.append(response['main']['temp'])
            humidity.append(response['main']['humidity'])
            wind.append(response['wind']['speed'])
            cloudiness.append(response['clouds']['all'])
            open_weather_city_number.append(response['id'])
            lat.append(response['coord']['lat'])
            lng.append(response['coord']['lon'])
            final_city_list.append(city)

            # Displaying a log of the last city for which weather data was successfully extracted 
            print(f"{process_number}, {city}, {response['id']}")

        # Displaying a log for the queries that resulted in an error
        except KeyError:
            print(f"{process_number}, {city}, Error: {response['message']}")
# Out:
# Process Number, City Name, City ID
# 1, fuxin, 2037346
# 2, turtkul, Error: city not found
# 3, flin flon, 5954718
# 4, rikitea, 4030556
# 5, norman wells, 6089245
# 6, albany, 5106834
# 7, longyan, 1802276
# 8, sentyabrskiy, Error: city not found
# 9, sioux lookout, 6148373
# 10, port alfred, 964432
# 11, chokurdakh, 2126123
# 12, vaini, 1273574
# 13, carnarvon, 1014034
# 14, constitucion, 4011743
# 15, hermanus, 3366880
# 16, slave lake, 6149374
# 17, nishihara, 1850144
# 18, morros, 3398381
# 19, mocambique, Error: city not found
# 20, ushuaia, 3833367
# 21, hithadhoo, 1282256
# 22, tasiilaq, 3424607
# 23, mandalgovi, 2030065
# 24, moerai, 4034188
# 25, price, 5545269
# 26, barentsburg, Error: city not found
# 27, opobo, Error: city not found
# 28, itarema, 3393692
# 29, hobart, 2163355
# 30, ouadda, 236901
# 31, lebu, 344979
# 32, mataura, 6201424
# 33, la rioja, 3848950
# 34, kapaa, 5848280
# 35, nikolskoye, 546105
# 36, punta arenas, 3874787
# 37, aleksandrov gay, 583345
# 38, fuling, 1810979
# 39, beringovskiy, 2126710
# 40, rock springs, 5836898
# 41, saldanha, 2737599
# 42, jamestown, 2069194
# 43, douentza, 2458334
# 44, port blair, 1259385
# 45, bathsheba, 3374083
# 46, egvekinot, 4031742
# 47, rundu, 3353383
# 48, zyryanka, 2119283
# 49, arraial do cabo, 3471451
# 50, agdam, 148619
# 51, najran, 103630
# 52, mizdah, 2214827
# 53, port elizabeth, 4501427
# 54, sao felix do xingu, 3388847
# 55, thompson, 6165406
# 56, ormara, 1168700
# 57, padang, 1633419
# 58, fortuna, 2517679
# 59, timmins, 6166739
# 60, new norfolk, 2155415
# 61, broome, 2656067
# 62, hilo, 5855927
# 63, khatanga, 2022572
# 64, san cristobal, 3652462
# 65, cabo san lucas, 3985710
# 66, moreira sales, 3456763
# 67, vila franca do campo, 3372472
# 68, acarau, Error: city not found
# 69, berlevag, 780687
# 70, shu, 1519030
# 71, monrovia, 2274895
# 72, road town, 3577430
# 73, rawlins, 5836068
# 74, castro, 3896218
# 75, saint anthony, 5606187
# 76, mbigou, 2398929
# 77, dordrecht, 2756669
# 78, pecos, 5528182
# 79, wanganui, 2179670
# 80, vardo, 4372777
# 81, georgetown, 3378644
# 82, amderma, Error: city not found
# 83, uray, 1488429
# 84, nosy varika, 1058080
# 85, cidreira, 3466165
# 86, kruisfontein, 986717
# 87, husavik, 5961417
# 88, coihaique, 3894426
# 89, sapa, 1715430
# 90, batie, 3014727
# 91, teguise, 2510573
# 92, faanui, 4034551
# 93, ngunguru, 2186111
# 94, bonavista, 5905393
# 95, atuona, 4020109
# 96, airai, 1651810
# 97, busselton, 2075265
# 98, cape town, 3369157
# 99, bam, 141736
# 100, bud, 7626370
# 101, iqaluit, 5983720
# 102, shetpe, 608324
# 103, rantepao, 1629974
# 104, taoudenni, 2450173
# 105, haines junction, 5969025
# 106, namatanai, 2090021
# 107, chuy, 3443061
# 108, izumo, 1861084
# 109, upernavik, 3418910
# 110, komsomolskiy, 1486910
# 111, nangomba, 877597
# 112, bethel, 5880568
# 113, saint george, 262462
# 114, belushya guba, Error: city not found
# 115, clyde river, 5924351
# 116, souillac, 3026644
# 117, te anau, 2181625
# 118, abu zabad, 380348
# 119, fulitun, Error: city not found
# 120, goderich, 5962442
# 121, malibu, 4196508
# 122, general roca, 3855065
# 123, tuatapere, 2180815
# 124, kopervik, 3149512
# 125, foumban, 2231506
# 126, avarua, 4035715
# 127, sanghar, 1176515
# 128, dunedin, 2191562
# 129, provideniya, 4031574
# 130, solnechnyy, 2016307
# 131, ciudad real, 2519402
# 132, taolanaro, Error: city not found
# 133, port-gentil, 2396518
# 134, puerto escondido, 3520994
# 135, barrow, 3833859
# 136, uaua, 3385883
# 137, asau, Error: city not found
# 138, faya, 110690
# 139, iquique, 3887127
# 140, kirakira, 2178753
# 141, tezu, 1254709
# 142, mayor pablo lagerenza, 3867427
# 143, saint-philippe, 6138908
# 144, port moresby, 2088122
# 145, kavaratti, 1267390
# 146, sur, 286245
# 147, ilulissat, 3423146
# 148, butaritari, 2110227
# 149, qaanaaq, 3831208
# 150, kodiak, 4407665
# 151, ust-karsk, 2013942
# 152, lalomanu, Error: city not found
# 153, mahebourg, 934322
# 154, pitimbu, 3391889
# 155, la ronge, 6050066
# 156, hohhot, 2036892
# 157, taltal, 3870243
# 158, sao geraldo do araguaia, 3388760
# 159, chudniv, 710381
# 160, yellowknife, 6185377
# 161, ojinaga, 3994469
# 162, jalu, 86049
# 163, tiksi, 2015306
# 164, tura, 1254046
# 165, marawi, 1701054
# 166, bredasdorp, 1015776
# 167, evreux, 3019265
# 168, mys shmidta, Error: city not found
# 169, goose creek, 4296212
# 170, caborca, 3996893
# 171, chancay, 3944399
# 172, ati, 2436400
# 173, walvis bay, 3359638
# 174, halifax, 6324729
# 175, victoria, 1733782
# 176, shingu, 1847947
# 177, saint-louis, 2978742
# 178, kashary, 552006
# 179, seoul, 1835848
# 180, canto do buriti, 3403251
# 181, attawapiskat, Error: city not found
# 182, barbar, Error: city not found
# 183, sukhoy log, 1490686
# 184, ancud, 3899695
# 185, kuala kedah, 1736305
# 186, mar del plata, 3863379
# 187, kazalinsk, Error: city not found
# 188, cacoal, 3925212
# 189, illoqqortoormiut, Error: city not found
# 190, yulara, 6355222
# 191, south lake tahoe, 5397664
# 192, longyearbyen, 2729907
# 193, franklin, 4623560
# 194, blue springs, 4377664
# 195, narsaq, 3421719
# 196, gao, 2457163
# 197, turinsk, 1488933
# 198, ilhabela, 3461425
# 199, platteville, 5267332
# 200, deputatskiy, 2028164
# 201, bengkulu, Error: city not found
# 202, ankazoabo, 1072879
# 203, suoyarvi, 486186
# 204, pevek, 2122090
# 205, puerto ayora, 3652764
# 206, talcahuano, 3870282
# 207, sumbawa, Error: city not found
# 208, sitka, 4267710
# 209, san patricio, 3437029
# 210, les cayes, 3728097
# 211, barabai, 1650064
# 212, waingapu, 1622318
# 213, toora-khem, 1489401
# 214, geraldton, 5960603
# 215, naze, 2337542
# 216, ostrovnoy, 556268
# 217, mount gambier, 2156643
# 218, mookane, 933290
# 219, port lincoln, 2063036
# 220, kenora, 5991056
# 221, akhmim, 361661
# 222, banff, 5892532
# 223, san vicente, 3583178
# 224, hami, 1529484
# 225, praia da vitoria, 3372760
# 226, sovetskiy, 490040
# 227, vaitupu, Error: city not found
# 228, kaputa, 176758
# 229, weligama, 1223738
# 230, viganello, 2658135
# 231, okato, 2185763
# 232, lodja, 211647
# 233, nizhnyaya salda, 1497393
# 234, notre-dame-du-lac, 6944109
# 235, gimli, 5961417
# 236, aksu, 1524298
# 237, atocha, 3660689
# 238, coquimbo, 3893629
# 239, watrous, 6176928
# 240, magadi, 1264514
# 241, grindavik, 3416888
# 242, puerto carreno, 3671519
# 243, ponta do sol, 3453439
# 244, palu, 1633034
# 245, puerto leguizamo, 3671437
# 246, miri, 2347470
# 247, karauzyak, Error: city not found
# 248, erzurum, 315368
# 249, gornyy, 559731
# 250, klaksvik, 2618795
# 251, dikson, 1507390
# 252, bundaberg, 2173323
# 253, roald, 3141667
# 254, mildura, 2157698
# 255, khormuj, Error: city not found
# 256, puerto el triunfo, 3584003
# 257, avera, 4231997
# 258, bardiyah, Error: city not found
# 259, athabasca, 5887916
# 260, la tuque, 6050416
# 261, luderitz, 3355672
# 262, takoradi, 2294915
# 263, bolungarvik, Error: city not found
# 264, fairbanks, 5861897
# 265, amla, 1278775
# 266, port arthur, 4720039
# 267, nanortalik, 3421765
# 268, fort nelson, 5955902
# 269, chapais, 5919850
# 270, bariri, 3470825
# 271, kieta, 2094027
# 272, isla mujeres, 3526756
# 273, cherskiy, 2126199
# 274, khed brahma, 1266806
# 275, vung tau, 1562414
# 276, killybegs, 2963295
# 277, tuktoyaktuk, 6170031
# 278, bluff, 2175403
# 279, wilmington, 4145381
# 280, ambon, 3037899
# 281, hualmay, 3939761
# 282, namibe, 3347019
# 283, alotau, Error: city not found
# 284, port hedland, 2063042
# 285, beloha, 1067565
# 286, magistralnyy, 2020584
# 287, saskylakh, 2017155
# 288, plettenberg bay, 964712
# 289, mormugao, Error: city not found
# 290, fernandez, 1715636
# 291, zlotoryja, 3080074
# 292, high level, 5975004
# 293, bandarbeyla, 64814
# 294, chopovychi, 710408
# 295, manikpur, 1263715
# 296, katherine, 2068655
# 297, torbay, 6167817
# 298, laguna, 4013704
# 299, thessalon, 6164831
# 300, moyale, 186180
# 301, sinkat, Error: city not found
# 302, dryden, 5942913
# 303, rongcheng, 1786855
# 304, karhal, 1267772
# 305, grand river south east, Error: city not found
# 306, carballo, 3126369
# 307, abha, 110690
# 308, caconda, 3351380
# 309, caravelas, 3466980
# 310, valparaiso, 4927537
# 311, ixtapa, 4004293
# 312, takob, Error: city not found
# 313, gangelt, 6553070
# 314, tumannyy, Error: city not found
# 315, nicoya, 3622716
# 316, polovinnoye, 1494523
# 317, richards bay, 962367
# 318, hovd, 7626384
# 319, oudtshoorn, 967106
# 320, ribeira grande, 3372707
# 321, palauig, 1696188
# 322, nantucket, 4944903
# 323, samarai, 2132606
# 324, lorengau, 2092164
# 325, pampa, 5527953
# 326, peque, 3672512
# 327, srednekolymsk, 2121025
# 328, lobito, 3347939
# 329, nizhneyansk, Error: city not found
# 330, saryshagan, Error: city not found
# 331, ondangwa, 3354247
# 332, copiapo, 3893656
# 333, krasnozerskoye, 1501988
# 334, sisophon, 1822207
# 335, pata, 3058531
# 336, dzhusaly, Error: city not found
# 337, alekseyevka, 548625
# 338, conde, 3465713
# 339, san pedro buenavista, 3523513
# 340, east london, 1006984
# 341, salalah, 286621
# 342, college, 5859699
# 343, russell, 3844421
# 344, warrnambool, 2144528
# 345, hun, 2790471
# 346, guarapari, 3461888
# 347, halmeu, 676351
# 348, kushima, 1895695
# 349, severo-kurilsk, 2121385
# 350, vangaindrano, 1054329
# 351, tagusao, 1684245
# 352, kumluca, 305681
# 353, matara, 3948642
# 354, atambua, 1651103
# 355, kango, 2400682
# 356, talnakh, 1490256
# 357, ruatoria, Error: city not found
# 358, xining, 1788852
# 359, karasjok, 779350
# 360, buala, 2109528
# 361, zabid, 69559
# 362, zhanatas, Error: city not found
# 363, sechura, 3691954
# 364, matadi, 2313002
# 365, christchurch, 2192362
# 366, amapa, 3603330
# 367, kamaishi, 2112444
# 368, kuusamo, 649924
# 369, baoro, 2389804
# 370, camana, Error: city not found
# 371, nehalim, 294093
# 372, meulaboh, 1214488
# 373, songea, 877401
# 374, teseney, 327651
# 375, palmas, 3474574
# 376, cangzhou, 1816080
# 377, kavieng, 2094342
# 378, gaoual, 2420826
# 379, north bend, 5742974
# 380, chuguyevka, 2025286
# 381, visby, 2662689
# 382, along, 1278969
# 383, aklavik, 5882953
# 384, ivanteyevka, 555111
# 385, kahului, 5847411
# 386, key west, 5059429
# 387, ewo, 2260009
# 388, burnie, 2173125
# 389, ahuimanu, 5856516
# 390, aberdeen, 5225857
# 391, barranca, 3946820
# 392, bilibino, 2126682
# 393, iznoski, 554776
# 394, kaitangata, 2208248
# 395, east brainerd, 4619943
# 396, gomel, Error: city not found
# 397, alice springs, 2077895
# 398, chhabra, 1274381
# 399, kingaroy, 2161376
# 400, qaqortoq, 3420846
# 401, atar, 2381334
# 402, orocue, 3673536
# 403, langsa, 1214724
# 404, coria, 2519234
# 405, boguchany, 1509844
# 406, digras, 1272596
# 407, opuwo, 3354077
# 408, sao filipe, 3374210
# 409, malindi, 187968
# 410, pilar, 3427208
# 411, awjilah, 88533
# 412, norton shores, 5004005
# 413, hit, 95788
# 414, korla, Error: city not found
# 415, shelburne, 6145890
# 416, vostok, 2013279
# 417, ketchikan, 5554428
# 418, saint-francois, 2980080
# 419, jumla, 1283285
# 420, sterling, 4787534
# 421, erzin, 296852
# 422, araouane, 2460954
# 423, muzhi, 1498161
# 424, watertown, 5232741
# 425, zhigansk, 2012530
# 426, fort saint james, 5881688
# 427, abu samrah, 172515
# 428, homer, 5864145
# 429, edd, 338345
# 430, palana, 2122262
# 431, balabac, 1728675
# 432, muroto, 1856392
# 433, mount isa, 2065594
# 434, skelleftea, 602913
# 435, whitehorse, 6180550
# 436, darnah, 87205
# 437, bela vista, 3470177
# 438, los llanos de aridane, 2514651
# 439, ca mau, 1586443
# 440, doha, 290030
# 441, camapua, 3468020
# 442, tomatlan, 3981391
# 443, bela vista de goias, 3470164
# 444, gold coast, 2165087
# 445, siocon, 1724435
# 446, ulaangom, 1515029
# 447, cockburn town, 3576994
# 448, qingdao, 1797929
# 449, mahon, 2965139
# 450, tazovskiy, 1489853
# 451, dingle, 1714733
# 452, marang, Error: city not found
# 453, kalaleh, 129512
# 454, pangnirtung, 6096551
# 455, santa luzia, 3450144
# 456, inongo, 2315417
# 457, biak, 1637001
# 458, monywa, 1308522
# 459, umtata, 946058
# 460, distraccion, 3685200
# 461, lolua, Error: city not found
# 462, wanning, 3220813
# 463, livingston, 4073383
# 464, ozernovskiy, 2122293
# 465, ballina, 2966778
# 466, chik, 1507873
# 467, cabra, 2520645
# 468, krasnoselkup, Error: city not found
# 469, darhan, 2031964
# 470, terrace, 6162949
# 471, sarahan, 1257277
# 472, codrington, 2160063
# 473, porosozero, 506232
# 474, samusu, Error: city not found
# 475, sinjai, 1626895
# 476, oxford, 4081914
# 477, lagoa, 2267254
# 478, pyay, 1299154
# 479, zhireken, 2012510
# 480, monteiro, 3394549
# 481, sambava, 1056899
# 482, luena, 3347719
# 483, virginia beach, 4791259
# 484, comodoro rivadavia, 3860443
# 485, carlton, 5020428
# 486, rapid valley, 5768244
# 487, elk city, 4535823
# 488, camacha, 2270385
# 489, sheridan, 5438542
# 490, uporovo, 1488465
# 491, satitoa, Error: city not found
# 492, raudeberg, 3146487
# 493, davila, 1715335
# 494, the valley, 3573374
# 495, grand centre, Error: city not found
# 496, tommot, 2015179
# 497, denpasar, 1645528
# 498, nome, 4732862
# 499, buchanan, 2278158
# 500, valdivia, 3868707
# 501, alindao, 240999
# 502, chalmette, 4319518
# 503, imbituba, 3461370
# 504, blonduos, Error: city not found
# 505, sao joao da barra, 3448903
# 506, luau, 876177
# 507, gollere, Error: city not found
# 508, marsa matruh, 352733
# 509, esperance, 3573739
# 510, aykhal, 2027296
# 511, charters towers, 2171722
# 512, dekar, 933815
# 513, bambous virieux, 1106677
# 514, necochea, 3430443
# 515, scottsburgh, Error: city not found
# 516, agadez, 2448085
# 517, grafton, 2164771
# 518, cabedelo, 3404558
# 519, mehamn, 778707
# 520, cumana, 3644768
# 521, sao gabriel da cachoeira, 3662342
# 522, dalvik, 2702977
# 523, lasa, 146639
# 524, taburi, Error: city not found
# 525, maturin, 3778045
# 526, flinders, 6255012
# 527, ingham, 2162737
# 528, bulolo, 2098869
# 529, sola, 643453
# 530, umzimvubu, Error: city not found
# 531, amahai, 1651591
# 532, ponta delgada, 3372783
# 533, rantauprapat, 1214073
# 534, lanivtsi, 703397
# 535, tsihombe, Error: city not found
# 536, kungurtug, 1501377
# 537, luanda, 2240449
# 538, shakawe, 933077
# 539, tahoua, 2439376
# 540, aras, 69559
# 541, tabiauea, Error: city not found
# 542, vila, 3164565
# 543, vilyuysk, 2013392
# 544, lompoc, 5367788
# 545, karasburg, 3356343
# 546, kamenka, 553725
# 547, alta floresta, 6316343
# 548, yuzhno-yeniseyskiy, Error: city not found
# 549, ribeira brava, 2263905
# 550, culiacan, 4012176
# 551, pacific grove, 5380437
# 552, kismayo, Error: city not found
# 553, kemin, 1528606
# 554, tidore, Error: city not found
# 555, opole lubelskie, 763107
# 556, tessalit, 2449893
# 557, roebourne, 2062276
# 558, asuncion, 3439389
# 559, primorsko-akhtarsk, 505259
# 560, kumla, 2698767
# 561, otofuke, 2128558
# 562, sabzevar, 118063
# 563, rovaniemi, 638936
# 564, arlit, 2447513
# 565, quatre cocos, 1106643
# 566, cap malheureux, 934649
# 567, chingola, 919009
# 568, soyo, 2236967
# 569, waw, Error: city not found
# 570, brigantine, 4500920
# 571, bantry, Error: city not found
# 572, katsuura, 1865309
# 573, rio gallegos, 3838859
# 574, ilinskoye-khovanskoye, 557060
# 575, santa maria, 3450083
# 576, svetlaya, 2015852

# %%
# Creating a dataframe from the now filled in weather data lists
weather_data_df = pd.DataFrame(data = final_city_list, columns = ["City"])

weather_data_df["Temperature"] = temp
weather_data_df["Humidity"] = humidity
weather_data_df["Wind Speed"] = wind
weather_data_df["Cloudiness"] = cloudiness
weather_data_df["Latitude"] = lat
weather_data_df["Longitude"] = lng
weather_data_df['OpenWeatherMap City Number'] = open_weather_city_number

# Checking the new df
weather_data_df.head(15)
weather_data_df.tail(15)

weather_data_df.describe(include="all").round(3)
# Out:
#                City  Temperature  Humidity  Wind Speed  Cloudiness  Latitude  \
# count           520      520.000   520.000     520.000     520.000   520.000
# unique          520          NaN       NaN         NaN         NaN       NaN
# top     alekseyevka          NaN       NaN         NaN         NaN       NaN
# freq              1          NaN       NaN         NaN         NaN       NaN
# mean            NaN       20.538    73.867       3.478      40.819    19.743
# std             NaN        8.275    22.802       2.236      35.491    33.334
# min             NaN       -1.140     7.000       0.020       0.000   -54.810
# 25%             NaN       14.712    61.000       1.870       0.000    -8.695
# 50%             NaN       22.510    79.000       3.035      40.000    24.735
# 75%             NaN       26.650    93.000       4.600      75.000    48.055
# max             NaN       43.000   100.000      13.710     100.000    78.220
#
#         Longitude  OpenWeatherMap City Number
# count     520.000                     520.000
# unique        NaN                         NaN
# top           NaN                         NaN
# freq          NaN                         NaN
# mean       11.563                 2796310.906
# std        88.396                 1703600.306
# min      -179.170                   64814.000
# 25%       -68.642                 1522981.000
# 50%        15.100                 2397723.500
# 75%        80.688                 3840249.500
# max       179.320                 7626384.000

# %%
# Setting up seaborn and the temperature and latitude scatterplot
sns.set()
plt.scatter(weather_data_df["Latitude"], weather_data_df["Temperature"])

# Setting titles & labels
plt.suptitle('City Temperature as a Function of Latitude', verticalalignment="baseline", weight="bold", fontsize=16)
plt.title(r"$temp \approx temp(lat)$")
plt.xlabel("Latitude")
plt.ylabel("Temperature")

# Creating a line at the equator
plt.axvline(0, color = 'black', alpha = .25, label = 'Equator')
plt.text(2,-20,'Equator', rotation=90)

# Trimming the axes 
plt.xlim(-80,100)
plt.ylim(-40, 50)


# # Saving up the chart
# total_fares_pie_chart_path = os.path.join('graphs_and_plots', 'pyber_total_fares_pie_chart.png')
# plt.savefig(total_fares_pie_chart_path, dpi=300, bbox_inches='tight')

# Displaying plot
plt.show()
