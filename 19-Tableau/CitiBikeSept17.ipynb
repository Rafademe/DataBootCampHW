# %% [markdown]
# ## CitiBike September 2017 Cleaning

# %%
import pandas as pd
import numpy as np
import time

# %%
Y = pd.read_csv("UCB_Repository/02-Homework/20-Tableau/Data/CitiBike-Sept2017.csv")

# %%
Y.head(2)
# Out:
#    Trip(Sec)  Trip(mins)    Date starttime  stoptime  start station id  \
# 0        362           6  9/1/17  00:00:17  00:06:19              3331
# 1        188           3  9/2/17  00:00:21  00:03:30              3101
#
#         start station name  start station latitude  start station longitude  \
# 0  Riverside Dr & W 104 St               40.801343               -73.971146
# 1    N 12 St & Bedford Ave               40.720798               -73.954847
#
#    end station id          end station name  end station latitude  \
# 0            3328  W 100 St & Manhattan Ave             40.795000
# 1            3100    Nassau Ave & Newell St             40.724813
#
#    end station longitude  bikeid    usertype  birth year   Age  gender Gender
# 0             -73.964500   14530  Subscriber      1993.0  25.0       1   Male
# 1             -73.947526   15475  Subscriber      1988.0  30.0       1   Male

# %%
## --- Drop --- ##  
Y2 = Y.drop(columns=["Trip(Sec)", "starttime", "stoptime", "bikeid", "birth year", "gender"])
Y2.head(5)
# Out:
#    Trip(mins)    Date  start station id        start station name  \
# 0           6  9/1/17              3331   Riverside Dr & W 104 St
# 1           3  9/2/17              3101     N 12 St & Bedford Ave
# 2           5  9/3/17              3140           1 Ave & E 78 St
# 3           4  9/4/17               236       St Marks Pl & 2 Ave
# 4          13  9/5/17              3427  Lafayette St & Jersey St
#
#    start station latitude  start station longitude  end station id  \
# 0               40.801343               -73.971146            3328
# 1               40.720798               -73.954847            3100
# 2               40.771404               -73.953517            3141
# 3               40.728419               -73.987140             473
# 4               40.724305               -73.996010            3431
#
#              end station name  end station latitude  end station longitude  \
# 0    W 100 St & Manhattan Ave             40.795000             -73.964500
# ...

# %%
Y2.to_csv("CitiBike-Sept2017.csv")

# %%
Y2.describe()
# Out:
#          Trip(mins)  start station id  start station latitude  \
# count  1.048575e+06      1.048575e+06            1.048575e+06
# mean   1.733211e+01      1.386939e+03            4.073612e+01
# std    1.602091e+02      1.354696e+03            4.898058e-02
# min    1.000000e+00      7.200000e+01            0.000000e+00
# 25%    7.000000e+00      3.630000e+02            4.071755e+01
# 50%    1.100000e+01      4.900000e+02            4.073650e+01
# 75%    1.900000e+01      3.146000e+03            4.075594e+01
# max    3.692600e+04      3.633000e+03            4.080862e+01
#
#        start station longitude  end station id  end station latitude  \
# count             1.048575e+06    1.048575e+06          1.048575e+06
# mean             -7.398491e+01    1.375523e+03          4.073554e+01
# std               7.427759e-02    1.351655e+03          1.014777e-01
# min              -7.402535e+01    7.200000e+01          0.000000e+00
# ...
